# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nmaes_64k = pd.read_excel("nmaesdf64.xlsx")

# %%
nmaes_64k.head()
# Out:
#    Unnamed: 0  nmaes_l0  nmaes_l1  nmaes_l2  nmaes_l3  nmaes_l4  nmaes_l5  \
# 0           0  0.027095  0.027443  0.027602  0.027400  0.026811  0.027165
# 1           1  0.028907  0.029435  0.028285  0.027981  0.030046  0.028031
# 2           2  0.028218  0.029576  0.028495  0.027964  0.032013  0.028195
# 3           3  0.028827  0.030337  0.028846  0.028116  0.031297  0.028210
# 4           4  0.029108  0.031628  0.028980  0.028128  0.035576  0.027828
#
#    nmaes_l6  nmaes_l7  nmaes_l8  ...  nmaes_l55  nmaes_l56  nmaes_l57  \
# 0  0.028186  0.026057  0.030655  ...   1.489065   0.037152        NaN
# 1  0.028540  0.026529  0.033524  ...   1.520656   0.035247        NaN
# 2  0.029038  0.026955  0.031009  ...   1.288925   0.048718        NaN
# 3  0.029009  0.027469  0.032015  ...   1.298733   0.068876        NaN
# 4  0.029410  0.027557  0.033020  ...   1.482461   0.136603        NaN
#
#    nmaes_l58  nmaes_l59  nmaes_l60  nmaes_l61  nmaes_l62  nmaes_l63  \
# ...

# %%
fig, linep_ = plt.subplots(figsize = (10,6), dpi = 100)

linep_ = sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l0", label="l=0", linewidth =1)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l1", label="l=1", linewidth =1.2)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l2", label="l=2", linewidth =1.2)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l3", label="l=3", linewidth =1.4)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l4", label="l=4", linewidth =1.6)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l5", label="l=5", linewidth =1.8)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l6", label="l=6", linewidth =2)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l7", label="l=7", linewidth =2.2)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l8", label="l=8", linewidth =2.4)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l9", label="l=9", linewidth =2.6)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l10", label="l=10", linewidth =2.8)
linep_.set(title="NMAE vs horizon for RNN model")

linep_.set(xlabel='h', ylabel='NMAE')
# Out:
# [Text(0, 0.5, 'NMAE'), Text(0.5, 0, 'h')]

# %%
fig, linep_ = plt.subplots(figsize = (10,6), dpi = 100)

linep_ = sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l11", label="l=11", linewidth =1)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l12", label="l=12", linewidth =1.2)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l13", label="l=13", linewidth =1.2)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l14", label="l=14", linewidth =1.4)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l15", label="l=15", linewidth =1.6)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l16", label="l=16", linewidth =1.8)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l17", label="l=17", linewidth =2)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l18", label="l=18", linewidth =2.2)
sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l19", label="l=19", linewidth =2.4)
#sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l20", label="l=20", linewidth =2.6)
#sns.lineplot(data=nmaes_64k, x=nmaes_64k.index, y="nmaes_l21", label="l=21", linewidth =2.8)
linep_.set(title="NMAE vs horizon for RNN model")

linep_.set(xlabel='h', ylabel='NMAE')
# Out:
# [Text(0, 0.5, 'NMAE'), Text(0.5, 0, 'h')]

# %%
nmaes_df = pd.read_excel("ARnmae.xlsx")

# %%
fig, linep_ = plt.subplots(figsize = (10,6), dpi = 100)

linep_ = sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l1", label="p=1", linewidth =1)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l2", label="p=2", linewidth =1.2)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l3", label="p=3", linewidth =1.4)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l4", label="p=4", linewidth =1.6)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l5", label="p=5", linewidth =1.8)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l6", label="p=6", linewidth =2)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l7", label="p=7", linewidth =2.2)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l8", label="p=8", linewidth =2.4)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l9", label="p=9", linewidth =2.6)
sns.lineplot(data=nmaes_df, x=nmaes_df.index, y="nmaes_l10", label="p=10", linewidth =2.8)
linep_.set(title="NMAE vs horizon value for AR model")

linep_.set(xlabel='h', ylabel='NMAE')
# Out:
# [Text(0, 0.5, 'NMAE'), Text(0.5, 0, 'h')]

# %%
fig.savefig('ARnmae.png', dpi=300, bbox_inches='tight')

# %%
h0 = [0.026367, 0.026595, 0.028552, 0.028122, 0.026822, 0.026414, 0.026160, 0.027066, 0.026467, 0.025973, 0.027344]
h1 = [0.028450, 0.028987, 0.026366, 0.025903, 0.026774, 0.027577, 0.026387, 0.027864, 0.025771, 0.025479, 0.027942]
h2 = [0.028953, 0.026854, 0.027764, 0.027637, 0.028060, 0.027208, 0.026186, 0.028374, 0.026779, 0.025826, 0.027125]
h3 = [0.029804, 0.030055, 0.027852, 0.027636, 0.027801, 0.027444, 0.026647, 0.029179, 0.027347, 0.026220, 0.029906]
h4 = [0.029093, 0.028284, 0.028251, 0.028271, 0.028876, 0.028015, 0.026872, 0.029193, 0.027710, 0.027473, 0.029507]
h5 = [0.030503, 0.028401, 0.028396, 0.027413, 0.031583, 0.027947, 0.026963, 0.029073, 0.027257, 0.027067, 0.029271]
h6 = [0.029115, 0.028414, 0.028836, 0.027557, 0.028279, 0.031677, 0.027151, 0.028105, 0.027565, 0.030286, 0.031423]
h7 = [0.028812, 0.029579, 0.028265, 0.027543, 0.028320, 0.028183, 0.027106, 0.029382, 0.027450, 0.030257, 0.030772]
h8 = [0.029688, 0.028476, 0.028658, 0.030983, 0.028613, 0.028888, 0.028742, 0.028260, 0.029367, 0.031818, 0.030349]
h9 = [0.029247, 0.029237, 0.031558, 0.029039, 0.028627, 0.028211, 0.028064, 0.028293, 0.028660, 0.032603, 0.029730]
h10 = [0.029210, 0.028866, 0.030199, 0.027901, 0.029137, 0.028341, 0.027797, 0.028322, 0.028102, 0.029495, 0.033650]

# %%
d = {'h0': h0, 'h1': h1, 'h2':h2, 'h3':h3, 'h4':h4, 'h5':h5, 'h6':h6, 'h7':h7, 'h8':h8, 'h9':h9, 'h10':h10}
nmaes_rnn_corrected = pd.DataFrame(data=d)

# %%
nmaes_rnn_corrected.head()
# Out:
#          h0        h1        h2        h3        h4        h5        h6  \
# 0  0.026367  0.028450  0.028953  0.029804  0.029093  0.030503  0.029115
# 1  0.026595  0.028987  0.026854  0.030055  0.028284  0.028401  0.028414
# 2  0.028552  0.026366  0.027764  0.027852  0.028251  0.028396  0.028836
# 3  0.028122  0.025903  0.027637  0.027636  0.028271  0.027413  0.027557
# 4  0.026822  0.026774  0.028060  0.027801  0.028876  0.031583  0.028279
#
#          h7        h8        h9       h10
# 0  0.028812  0.029688  0.029247  0.029210
# 1  0.029579  0.028476  0.029237  0.028866
# 2  0.028265  0.028658  0.031558  0.030199
# 3  0.027543  0.030983  0.029039  0.027901
# 4  0.028320  0.028613  0.028627  0.029137

# %%
fig, linep_ = plt.subplots(figsize = (10,6), dpi = 100)

linep_ = sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h0", label="h=0", linewidth =1)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h1", label="h=1", linewidth =1)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h2", label="h=2", linewidth =1.2)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h3", label="h=3", linewidth =1.4)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h4", label="h=4", linewidth =1.6)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h5", label="h=5", linewidth =1.8)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h6", label="h=6", linewidth =2)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h7", label="h=7", linewidth =2.2)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h8", label="h=8", linewidth =2.4)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h9", label="h=9", linewidth =2.6)
sns.lineplot(data=nmaes_rnn_corrected, x=nmaes_rnn_corrected.index, y="h10", label="h=10", linewidth =2.8)
linep_.set(title="NMAE vs lag value for RNN model")

linep_.set(xlabel='lag', ylabel='NMAE')
# Out:
# [Text(0, 0.5, 'NMAE'), Text(0.5, 0, 'lag')]

# %%
fig.savefig('nmaernncorr.png', dpi=300, bbox_inches='tight')

# %%
nmaes_q1 = [0.022795, 0.036474, 0.046999, 0.057806, 0.068842, 0.079894, 0.091058, 0.102502, 0.114425, 0.126540, 0.139031]
nmaes_q2 = [0.020268444935871537, 0.033572082427815106, 0.04699959586886911, 0.057806934838007765, 0.0688426870949042, 0.07989457443870815, 0.09105915759705513, 0.1025031661740809, 0.11442618313071577, 0.12654131069948, 0.1390319656419216]
nmaes_q3 = [0.020544891651949393, 0.03302454538882994, 0.04611042254405253, 0.05780620105027403, 0.06884192676516186, 0.07989382735335014, 0.0910584426918028, 0.10250245843902353, 0.11442541014906707, 0.12654050615755522, 0.13903118378909285]
nmaes_q4 = [0.020176480760983318, 0.03297682758395667, 0.04552158424229804, 0.05706580936368814, 0.06884207380951478, 0.07989401671432678, 0.09105864389960848, 0.10250262962338888, 0.11442558273296338, 0.12654069756122957, 0.13903139008432824]
nmaes_q5 = [0.019412161904150755, 0.03196134095585803, 0.04428455913803603, 0.055505321977343404, 0.06733029554653797, 0.07989431373828916, 0.09105892859631672, 0.102502911130387, 0.11442587971491663, 0.12654100271666635, 0.13903168303860788]
nmaes_q6 = [0.019104550494311787, 0.031270557798257326, 0.0430644119814718, 0.05411695051841191, 0.06588203597484617, 0.0786696262595417, 0.09105922406283712, 0.1025032149556471, 0.11442619340753933, 0.12654130224577564, 0.13903199844604658]
nmaes_q7 = [0.018886435604565776, 0.030900866874740206, 0.04244373996684563, 0.05320188530399197, 0.06484362871499935, 0.07775614499685511, 0.09041098982075617, 0.10250327216471006, 0.11442624669652877, 0.1265413663634638, 0.13903207125209904]
nmaes_q8 = [0.018851140371004875, 0.030581341923499154, 0.04206103446253349, 0.05265998973326961, 0.06411043945347698, 0.07710020842021753, 0.08988314730397964, 0.10202531649569754, 0.11442613486157201, 0.12654126502057078, 0.13903196196982312]
nmaes_q9 = [0.0185378549934669, 0.03028447857620228, 0.041477294081816385, 0.05198947686731554, 0.06351913276327777, 0.07651514007089123, 0.08936925257321356, 0.10149508208687823, 0.1139977540589933, 0.1265415329265209, 0.1390322319031397]

# %%
d = {'nmaes_q1': nmaes_q1, 'nmaes_q2': nmaes_q2, 'nmaes_q3':nmaes_q3, 'nmaes_q4':nmaes_q4, 'nmaes_q5':nmaes_q5, 'nmaes_q6':nmaes_q6, 'nmaes_q7':nmaes_q7, 'nmaes_q8':nmaes_q8, 'nmaes_q9':nmaes_q9}
nmaes_MA = pd.DataFrame(data=d)

# %%
nmaes_MA.to_excel("nmaesMAAA.xlsx")

# %%
fig, linep_ = plt.subplots(figsize = (10,6), dpi = 100)

linep_ = sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q1", label="q=1",  linewidth =4.4)
sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q2", label="q=2",  linewidth =4)
sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q3", label="q=3",  linewidth =3.6)
sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q4", label="q=4", linewidth =3.2)
sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q5", label="q=5", linewidth =2.8)
sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q6", label="q=6", linewidth =2.4)
sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q7", label="q=7", linewidth =2)
sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q8", label="q=8", linewidth =1.6)
sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q9", label="q=9", linewidth =1.2)
#sns.lineplot(data=nmaes_MA, x=nmaes_MA.index, y="nmaes_q10", label="q=10", linewidth =1)
linep_.set(yscale="log")
linep_.set(title="NMAE vs horizon value for MA model") 

linep_.set(xlabel='h', ylabel='NMAE')
# Out:
# [Text(0, 0.5, 'NMAE'), Text(0.5, 0, 'h')]

# %%
fig.savefig('MAnmae.png', dpi=300, bbox_inches='tight')
